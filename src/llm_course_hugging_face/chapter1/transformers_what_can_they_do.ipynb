# %%
import sys # To use virtual environment set by Poetry
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 15833.88it/s]
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
# We can even pass several sentences!
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598049521446228},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 515/515 [00:00<00:00, 3330.76it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445963859558105, 0.11197596788406372, 0.04342765361070633]}

# %%
generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 326/326 [00:00<00:00, 5085.88it/s]
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to create a simple banking system in Python. You will learn the basics of object-oriented programming, including classes and objects, and how to use them to model a bank account.\n\nHere's a brief outline of what you'll learn in this course:\n\n1. **Introduction to Python and Object-Oriented Programming**: You'll learn the basics of Python, including variables, data types, and control structures. You'll also learn about object-oriented programming, including classes and objects.\n\n2. **Creating a Bank Account Class**: You'll create a BankAccount class that has attributes for the account number, account holder's name, and balance. You'll also create methods for depositing and withdrawing money from the account.\n\n3. **Implementing Bank Account Operations**: You'll implement the deposit and withdraw methods for the BankAccount class. You'll also add error checking to handle cases where the user tries to withdraw more money than they have in their account.\n\n4. **Testing the Bank Account Class**: You'll test the BankAccount class by creating instances of it and performing various operations on them.\n\n5. **Using Inheritance and Polymorphism**: You'll learn about inheritance and polymorphism, and use them to create a more complex banking system with different types of accounts (e.g. checking,"}]

# %%
generator = pipeline("text-generation")
generator(
    "In this course, we will teach you how to",
    max_length=15,
    num_return_sequences=2,
)
# Out:
# No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 326/326 [00:00<00:00, 4602.83it/s]
# Both `max_new_tokens` (=256) and `max_length`(=15) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to write a Python program that uses the Pygame library to create a simple video game. Specifically, we will create a game where you control a character that moves left and right, and you have to avoid obstacles.\n\nHere is a list of the topics we will cover:\n\n*   Installing Python and Pygame\n*   Importing Pygame modules\n*   Creating a game window\n*   Drawing objects on the screen\n*   Handling events (key presses and mouse movements)\n*   Updating the game state\n*   Rendering the game state\n\nPlease note that you will need to have Python and Pygame installed on your computer in order to run this code. If you don't have them installed, you can download them from the official websites.\n\nLet's get started!\n\n**Installing Python and Pygame**\n\nBefore we begin, let's make sure you have Python and Pygame installed on your computer.\n\nTo install Python, you can download the latest version from the official website: [Python Download](https://www.python.org/downloads/). Follow the installation instructions for your operating system.\n\nTo install Pygame, you can download the latest version from the official website: [Pygame Download](https://www.pygame.org/page/download.html). Follow the installation instructions for your operating system.\n\n"},
#  {'generated_text': 'In this course, we will teach you how to write your own computer programs. You will learn how to use a programming language like Python to solve problems, create games, and build websites. You will also learn how to use version control with Git to manage your projects and collaborate with others.\n\nYou will need to have a computer with a web browser to access the course materials, and some basic knowledge of what a computer is and how to use a mouse and keyboard.\n\nTo get the most out of this course, you should be able to:\n\n* Open a web browser and navigate to a website\n* Click on links and buttons\n* Type text using your keyboard\n* Copy and paste text from one place to another\n\nHere are the step-by-step instructions for how to get started with the course:\n\n1. Open a web browser on your computer.\n2. Go to the course website and click on the "Start" button.\n3. Click on the "Enroll" button to register for the course.\n4. Follow the prompts to create an account and choose a password.\n5. Once you are enrolled, click on the "Course Materials" tab to access the course content.\n6. Click on the "Module 1" tab to start with the first module.\n7. Click on the "Lesson 1" tab'}]

# %%
generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 8445.45it/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to use these strategies in a wide variety of situations.\n\nFor example, you might need to decide how to spend your allowance money or how to save up for something special. You could use your budget to make sure you don't spend more than you can afford. You could also use your budget to plan trips, like going to the movies or a picnic with friends.\n\nAnother example might involve making decisions about what to do with your money. Maybe you want to go to the movies with your family, but you're not sure what to buy them. You could use your budget to decide which movies to see and which snacks to bring. You could even use your budget to decide whether to buy a new video game or a new pair of sneakers.\n\nBudgeting isn't just for kids! It's a skill that professionals use all the time. For example, doctors and nurses often use budgets to decide how much medicine or equipment they need to provide to patients. Teachers also use budgets to plan lessons and activities for their classes. And construction workers use budgets to estimate how much it will cost to build new buildings or roads.\n\nIn this course, we'll teach you all about budgeting so that you can be a responsible and smart consumer. By the end"},
#  {'generated_text': "In this course, we will teach you how to effectively use a digital camera to capture stunning photographs of the world around you. Whether you're a budding photographer or simply curious about the latest technology, this course is for you!\n\n**What is a Digital Camera?**\n\nA digital camera is a device that takes pictures. It uses a special kind of light detection called a sensor to record light, which is then turned into an image. Think of it like a camera on steroids!\n\n**Why Should I Learn About Digital Cameras?**\n\nLearning about digital cameras will help you understand how to make better photos, create more impressive slideshows, and even take cool shots of your own house or classroom! Plus, it's super fun to try out new things and make your own creations!\n\n**Step 1: Gather Your Materials**\n\nTo start, you'll need some basic items:\n\n* A digital camera (a fancy name for a camera phone)\n* A computer with internet access\n* A device to capture images, such as a tablet or smartphone\n* A flat surface to place your camera\n\nIf you don't have these things, ask someone nearby for assistance. They might be able to lend you one of their devices or lend you a friend's camera.\n"}]
